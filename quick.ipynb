# %%
import pickle as pkl
import numpy as np

# %%
with open("figures/mnist/1/sift_entropy.pkl", 'rb') as f:
    print(np.mean(pkl.load(f)))
# Out:
# 2.3475733734196993

# %%
with open("figures/flowers/1/histogram_entropy.pkl", 'rb') as f:
    print(np.nanmean(pkl.load(f)))
# Out:
# 4.209474400714569

# %%
import numpy as np
import cv2 as cv

img = cv.imread('jpg/image_00001.jpg')
gray= cv.cvtColor(img,cv.COLOR_BGR2GRAY)
sift = cv.SIFT_create()
kp = sift.detect(gray,None)
img=cv.drawKeypoints(gray,kp,img)
cv.imwrite('sift_keypoints.jpg',img)
# Out:
# True
